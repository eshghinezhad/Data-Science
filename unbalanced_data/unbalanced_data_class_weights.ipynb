# %% [markdown]
# <a href="https://colab.research.google.com/github/eshghinezhad/Data-Science/blob/master/unbalanced_data/unbalanced_data_class_weights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1 — Create Imbalanced Data

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# Create imbalanced dataset
X, y = make_classification(
    n_samples=1000,
    n_features=2,
    n_informative=2,
    n_redundant=0,
    weights=[0.99, 0.01],  # 99% normal, 1% fraud
    random_state=42
)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %% [markdown]
# Step 2 — Train Naive Model (No Fix)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[296   0]
#  [  4   0]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       296
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.99       300
#    macro avg       0.49      0.50      0.50       300
# weighted avg       0.97      0.99      0.98       300
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# Step 3 — Fix Using Class Weights

# %%
model_weighted = LogisticRegression(class_weight='balanced')
model_weighted.fit(X_train, y_train)

y_pred_weighted = model_weighted.predict(X_test)

print(confusion_matrix(y_test, y_pred_weighted))
print(classification_report(y_test, y_pred_weighted))
# Out:
# [[248  48]
#  [  2   2]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.84      0.91       296
#            1       0.04      0.50      0.07         4
#
#     accuracy                           0.83       300
#    macro avg       0.52      0.67      0.49       300
# weighted avg       0.98      0.83      0.90       300

# %% [markdown]
# Recall for minority class increases
#
# Accuracy may drop slightly
#
# Model is actually useful now
